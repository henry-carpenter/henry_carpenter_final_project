# %% [markdown]
# ### Henry Carpenter - Final Project, Part 2: Early attempts at a model

# %%
#  Loading in the relevant packages

import re
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# %matplotlib inline

# %%
#  Loading in the files that weren't too large to remain single files
listings_df = pd.read_csv('./listings.csv')
neighbourhoods_df = pd.read_csv('./neighbourhoods.csv')
reviews_df = pd.read_csv('./reviews.csv')

# %%
#  Loading in the files that had to be split into several pieces
listings_1_df = pd.read_csv('./listings_1.csv')
listings_2_df = pd.read_csv('./listings_2.csv')
listings_3_df = pd.read_csv('./listings_3.csv')
listings_4_df = pd.read_csv('./listings_4.csv')

# %%
#  Loading in the files that had to be split into several pieces
calendar_1_df = pd.read_csv('./calendar_1.csv')
calendar_2_df = pd.read_csv('./calendar_1.csv')
calendar_3_df = pd.read_csv('./calendar_1.csv')
calendar_4_df = pd.read_csv('./calendar_1.csv')

# %%
#  Loading in the files that had to be split into several pieces
reviews_1_df = pd.read_csv('./reviews_1.csv')
reviews_2_df = pd.read_csv('./reviews_2.csv')
reviews_3_df = pd.read_csv('./reviews_3.csv')
reviews_4_df = pd.read_csv('./reviews_4.csv')
reviews_5_df = pd.read_csv('./reviews_5.csv')
reviews_6_df = pd.read_csv('./reviews_6.csv')

# %%
#  Appending the several smaller files to recreate the inital larger file
reviews_summary_df = reviews_1_df.append(reviews_2_df.append(reviews_3_df.append(reviews_4_df.append(reviews_5_df.append(reviews_6_df))))).drop(columns=['Unnamed: 0'], axis='columns')
listings_summary_df = listings_1_df.append(listings_2_df).drop(columns=['Unnamed: 0'], axis='columns')
calendar_df = calendar_1_df.append(calendar_2_df.append(calendar_3_df.append(calendar_4_df))).drop(columns=['Unnamed: 0'], axis='columns')

# %%
#  Dropping features I decided initially seemed unhelful (wih the help of heatmaps and correlations) and creating dummy variables for others
labels_to_drop_listings = ['price', 'is_business_travel_ready', 'require_guest_phone_verification', 'host_id', 'has_availability', 'calendar_updated', 'availability_30', 'availability_60', 'availability_90', 'availability_365', 'extra_people', 'guests_included', 'cleaning_fee', 'security_deposit','monthly_price', 'weekly_price', 'square_feet', 'amenities', 'property_type', 'latitude', 'longitude', 'is_location_exact', 'zipcode', 'market', 'city', 'state', 'smart_location', 'country_code', 'country', 'host_verifications', 'host_has_profile_pic', 'host_identity_verified', 'street', 'neighbourhood', 'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'host_response_rate', 'host_acceptance_rate', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'host_listings_count', 'host_total_listings_count', 'calendar_last_scraped', 'first_review', 'last_review', 'experiences_offered', 'xl_picture_url', 'host_url', 'host_name', 'host_since', 'host_location', 'host_about', 'host_response_time', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'requires_license', 'notes', 'transit', 'access', 'interaction', 'house_rules', 'thumbnail_url', 'medium_url', 'picture_url', 'review_scores_location', 'review_scores_value', 'license', 'jurisdiction_names','listing_url', 'scrape_id', 'last_scraped', 'name', 'summary', 'space', 'description', 'neighborhood_overview', 'require_guest_profile_picture', 'calculated_host_listings_count']
listings_summary_df.drop(labels=labels_to_drop_listings, axis='columns', inplace=True)
listings_summary_df = pd.get_dummies(listings_summary_df, columns=['cancellation_policy', 'bed_type', 'room_type'], drop_first=True)

# %%
#  Converting boolean values into integer
listings_summary_df.loc[:, ['instant_bookable', 'host_is_superhost']] = (listings_summary_df.loc[:, ['instant_bookable', 'host_is_superhost']] == 'f')
listings_summary_df.loc[:, ['instant_bookable', 'host_is_superhost']] = listings_summary_df.loc[:, ['instant_bookable', 'host_is_superhost']].astype(int)

# %%
#  Merging the calendar dataframe with the listings one to match up only on available days
#  I initially included features like 'month', 'is_weekend', 'days_from_beginning', etc but they turned out to have effectively no correlation with price at all
large_df = pd.merge(calendar_df, listings_summary_df, how='left', left_on = 'listing_id', right_on = 'id')
large_df.drop(labels=['id'], axis='columns', inplace=True)

# %%
#  Drop unusable rows
large_df = large_df.dropna()
X = large_df.drop('price', axis='columns')
y = large_df.loc[:, 'price']
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
#  5-fold cross-validation
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
scoring = ['r2', 'neg_mean_squared_error']
lr_bnb = LinearRegression()
kf = KFold(5, shuffle=True)
lr_grid = GridSearchCV(estimator=lr_bnb, param_grid={}, scoring=scoring, refit='r2', cv=kf, return_train_score=True)

#  Using RMSE and R^2 as my success metrics
lr_grid.fit(X,y)
results = lr_grid.cv_results_
print('Mean test RMSE: ', np.sqrt(-1*results['mean_test_neg_mean_squared_error']))
print('Mean train RMSE: ', np.sqrt(-1*results['mean_train_neg_mean_squared_error']))
print('Mean test R^2: ', results['mean_test_r2'])
print('Mean train R^2: ', results['mean_train_r2'])
# Out:
# Mean test RMSE:  [46.23058644]
# Mean train RMSE:  [46.2285093]
# Mean test R^2:  [0.39387658]
# Mean train R^2:  [0.3939226]

# %%
large_df.corr()
# Out:
#                                                  listing_id     price  \
# listing_id                                         1.000000 -0.003729
# price                                             -0.003729  1.000000
# host_is_superhost                                 -0.027378 -0.069581
# accommodates                                      -0.054674  0.486377
# bathrooms                                          0.028655  0.313973
# bedrooms                                          -0.032484  0.505592
# beds                                              -0.075671  0.395776
# minimum_nights                                    -0.075325 -0.047295
# maximum_nights                                     0.043375  0.010683
# number_of_reviews                                 -0.139354  0.021260
# review_scores_rating                               0.032496  0.054454
# instant_bookable                                   0.044545 -0.068191
# reviews_per_month                                  0.047304  0.013114
# cancellation_policy_moderate                       0.031995 -0.062391
# cancellation_policy_strict_14_with_grace_period   -0.076878  0.107987
# bed_type_Couch                                     0.030867  0.025581
# bed_type_Futon                                     0.029352 -0.059969
# bed_type_Pull-out Sofa                             0.016262 -0.091895
# bed_type_Real Bed                                 -0.040292  0.097855
# room_type_Private room                             0.097214 -0.359554
# room_type_Shared room                              0.035981 -0.087744
#
#                                                  host_is_superhost  \
# listing_id                                               -0.027378
# price                                                    -0.069581
# host_is_superhost                                         1.000000
# accommodates                                              0.013257
# bathrooms                                                -0.040355
# bedrooms                                                 -0.005358
# beds                                                      0.030376
# minimum_nights                                            0.118354
# maximum_nights                                            0.021516
# number_of_reviews                                        -0.369162
# review_scores_rating                                     -0.266546
# instant_bookable                                          0.034052
# reviews_per_month                                        -0.354830
# cancellation_policy_moderate                             -0.024490
# cancellation_policy_strict_14_with_grace_period           0.005418
# bed_type_Couch                                            0.007202
# bed_type_Futon                                            0.008479
# bed_type_Pull-out Sofa                                    0.012380
# bed_type_Real Bed                                        -0.016140
# room_type_Private room                                   -0.069841
# room_type_Shared room                                     0.042907
#
#                                                  accommodates  bathrooms  \
# listing_id                                          -0.054674   0.028655
# price                                                0.486377   0.313973
# host_is_superhost                                    0.013257  -0.040355
# accommodates                                         1.000000   0.282983
# bathrooms                                            0.282983   1.000000
# bedrooms                                             0.661266   0.378183
# beds                                                 0.808334   0.264687
# minimum_nights                                      -0.039157  -0.020646
# maximum_nights                                       0.028333  -0.007852
# number_of_reviews                                    0.114778  -0.001475
# review_scores_rating                                -0.153241   0.065996
# instant_bookable                                    -0.155234  -0.019000
# reviews_per_month                                    0.101074   0.006529
# cancellation_policy_moderate                        -0.042582  -0.035006
# cancellation_policy_strict_14_with_grace_period      0.122468   0.030692
# bed_type_Couch                                      -0.037854  -0.046045
# bed_type_Futon                                      -0.078361  -0.018782
# bed_type_Pull-out Sofa                              -0.098329  -0.047397
# bed_type_Real Bed                                    0.132100   0.063859
# room_type_Private room                              -0.388546  -0.021248
# room_type_Shared room                                0.150963  -0.163130
#
#                                                  bedrooms      beds  \
# listing_id                                      -0.032484 -0.075671
# price                                            0.505592  0.395776
# host_is_superhost                               -0.005358  0.030376
# accommodates                                     0.661266  0.808334
# bathrooms                                        0.378183  0.264687
# bedrooms                                         1.000000  0.648588
# beds                                             0.648588  1.000000
# minimum_nights                                  -0.023551 -0.023150
# maximum_nights                                  -0.004318  0.007136
# number_of_reviews                               -0.002011  0.045691
# review_scores_rating                            -0.027698 -0.160372
# instant_bookable                                -0.038639 -0.092854
# reviews_per_month                               -0.006133  0.028627
# cancellation_policy_moderate                    -0.016368 -0.017164
# cancellation_policy_strict_14_with_grace_period  0.052397  0.061966
# bed_type_Couch                                  -0.043065 -0.032801
# bed_type_Futon                                  -0.047254 -0.047804
# bed_type_Pull-out Sofa                          -0.060277 -0.088247
# bed_type_Real Bed                                0.089079  0.106590
# room_type_Private room                          -0.211334 -0.302090
# room_type_Shared room                           -0.042116  0.229646
#
#                                                  minimum_nights  \
# listing_id                                            -0.075325
# price                                                 -0.047295
# host_is_superhost                                      0.118354
# accommodates                                          -0.039157
# bathrooms                                             -0.020646
# bedrooms                                              -0.023551
# beds                                                  -0.023150
# minimum_nights                                         1.000000
# maximum_nights                                         0.075176
# number_of_reviews                                     -0.116843
# review_scores_rating                                   0.046641
# instant_bookable                                       0.079697
# reviews_per_month                                     -0.148244
# cancellation_policy_moderate                          -0.061822
# cancellation_policy_strict_14_with_grace_period        0.104912
# bed_type_Couch                                        -0.025471
# bed_type_Futon                                        -0.033568
# bed_type_Pull-out Sofa                                -0.025687
# bed_type_Real Bed                                      0.048585
# room_type_Private room                                -0.189646
# room_type_Shared room                                 -0.038177
#
#                                                  maximum_nights  \
# listing_id                                             0.043375
# price                                                  0.010683
# host_is_superhost                                      0.021516
# accommodates                                           0.028333
# bathrooms                                             -0.007852
# bedrooms                                              -0.004318
# beds                                                   0.007136
# minimum_nights                                         0.075176
# maximum_nights                                         1.000000
# number_of_reviews                                     -0.008740
# review_scores_rating                                  -0.008177
# instant_bookable                                      -0.020626
# reviews_per_month                                     -0.002171
# cancellation_policy_moderate                          -0.016198
# cancellation_policy_strict_14_with_grace_period        0.005978
# bed_type_Couch                                        -0.006999
# bed_type_Futon                                        -0.021254
# bed_type_Pull-out Sofa                                -0.012163
# bed_type_Real Bed                                      0.024182
# room_type_Private room                                -0.046396
# room_type_Shared room                                 -0.025114
#
#                                                  number_of_reviews  \
# listing_id                                               -0.139354
# price                                                     0.021260
# host_is_superhost                                        -0.369162
# accommodates                                              0.114778
# bathrooms                                                -0.001475
# bedrooms                                                 -0.002011
# beds                                                      0.045691
# minimum_nights                                           -0.116843
# maximum_nights                                           -0.008740
# number_of_reviews                                         1.000000
# review_scores_rating                                     -0.033109
# instant_bookable                                         -0.292851
# reviews_per_month                                         0.909697
# cancellation_policy_moderate                             -0.002834
# cancellation_policy_strict_14_with_grace_period           0.061904
# bed_type_Couch                                            0.021587
# bed_type_Futon                                           -0.023071
# bed_type_Pull-out Sofa                                   -0.005994
# bed_type_Real Bed                                         0.013197
# room_type_Private room                                   -0.014000
# room_type_Shared room                                     0.000062
#
#                                                          ...            \
# listing_id                                               ...
# price                                                    ...
# host_is_superhost                                        ...
# accommodates                                             ...
# bathrooms                                                ...
# bedrooms                                                 ...
# beds                                                     ...
# minimum_nights                                           ...
# maximum_nights                                           ...
# number_of_reviews                                        ...
# review_scores_rating                                     ...
# instant_bookable                                         ...
# reviews_per_month                                        ...
# cancellation_policy_moderate                             ...
# cancellation_policy_strict_14_with_grace_period          ...
# bed_type_Couch                                           ...
# bed_type_Futon                                           ...
# bed_type_Pull-out Sofa                                   ...
# bed_type_Real Bed                                        ...
# room_type_Private room                                   ...
# room_type_Shared room                                    ...
#
#                                                  instant_bookable  \
# listing_id                                               0.044545
# price                                                   -0.068191
# host_is_superhost                                        0.034052
# accommodates                                            -0.155234
# bathrooms                                               -0.019000
# bedrooms                                                -0.038639
# beds                                                    -0.092854
# minimum_nights                                           0.079697
# maximum_nights                                          -0.020626
# number_of_reviews                                       -0.292851
# review_scores_rating                                     0.116142
# instant_bookable                                         1.000000
# reviews_per_month                                       -0.303973
# cancellation_policy_moderate                             0.005339
# cancellation_policy_strict_14_with_grace_period         -0.025746
# bed_type_Couch                                          -0.040150
# bed_type_Futon                                           0.053868
# bed_type_Pull-out Sofa                                   0.052870
# bed_type_Real Bed                                       -0.059368
# room_type_Private room                                   0.126266
# room_type_Shared room                                    0.037043
#
#                                                  reviews_per_month  \
# listing_id                                                0.047304
# price                                                     0.013114
# host_is_superhost                                        -0.354830
# accommodates                                              0.101074
# bathrooms                                                 0.006529
# bedrooms                                                 -0.006133
# beds                                                      0.028627
# minimum_nights                                           -0.148244
# maximum_nights                                           -0.002171
# number_of_reviews                                         0.909697
# review_scores_rating                                     -0.023298
# instant_bookable                                         -0.303973
# reviews_per_month                                         1.000000
# cancellation_policy_moderate                              0.024596
# cancellation_policy_strict_14_with_grace_period           0.034486
# bed_type_Couch                                            0.017940
# bed_type_Futon                                           -0.009851
# bed_type_Pull-out Sofa                                    0.012672
# bed_type_Real Bed                                        -0.008825
# room_type_Private room                                    0.030980
# room_type_Shared room                                     0.014344
#
#                                                  cancellation_policy_moderate  \
# listing_id                                                           0.031995
# price                                                               -0.062391
# host_is_superhost                                                   -0.024490
# accommodates                                                        -0.042582
# bathrooms                                                           -0.035006
# bedrooms                                                            -0.016368
# beds                                                                -0.017164
# minimum_nights                                                      -0.061822
# maximum_nights                                                      -0.016198
# number_of_reviews                                                   -0.002834
# review_scores_rating                                                 0.052520
# instant_bookable                                                     0.005339
# reviews_per_month                                                    0.024596
# cancellation_policy_moderate                                         1.000000
# cancellation_policy_strict_14_with_grace_period                     -0.750282
# bed_type_Couch                                                      -0.017859
# bed_type_Futon                                                      -0.010279
# bed_type_Pull-out Sofa                                               0.039307
# bed_type_Real Bed                                                   -0.024659
# room_type_Private room                                               0.087462
# room_type_Shared room                                                0.028034
#
#                                                  cancellation_policy_strict_14_with_grace_period  \
# listing_id                                                                             -0.076878
# price                                                                                   0.107987
# host_is_superhost                                                                       0.005418
# accommodates                                                                            0.122468
# bathrooms                                                                               0.030692
# bedrooms                                                                                0.052397
# beds                                                                                    0.061966
# minimum_nights                                                                          0.104912
# maximum_nights                                                                          0.005978
# number_of_reviews                                                                       0.061904
# review_scores_rating                                                                   -0.040213
# instant_bookable                                                                       -0.025746
# reviews_per_month                                                                       0.034486
# cancellation_policy_moderate                                                           -0.750282
# cancellation_policy_strict_14_with_grace_period                                         1.000000
# bed_type_Couch                                                                          0.001850
# bed_type_Futon                                                                          0.024088
# bed_type_Pull-out Sofa                                                                 -0.037360
# bed_type_Real Bed                                                                       0.019404
# room_type_Private room                                                                 -0.191364
# room_type_Shared room                                                                  -0.008871
#
#                                                  bed_type_Couch  \
# listing_id                                             0.030867
# price                                                  0.025581
# host_is_superhost                                      0.007202
# accommodates                                          -0.037854
# bathrooms                                             -0.046045
# bedrooms                                              -0.043065
# beds                                                  -0.032801
# minimum_nights                                        -0.025471
# maximum_nights                                        -0.006999
# number_of_reviews                                      0.021587
# review_scores_rating                                  -0.027321
# instant_bookable                                      -0.040150
# reviews_per_month                                      0.017940
# cancellation_policy_moderate                          -0.017859
# cancellation_policy_strict_14_with_grace_period        0.001850
# bed_type_Couch                                         1.000000
# bed_type_Futon                                        -0.011923
# bed_type_Pull-out Sofa                                -0.016789
# bed_type_Real Bed                                     -0.323491
# room_type_Private room                                 0.035806
# room_type_Shared room                                  0.067640
#
#                                                  bed_type_Futon  \
# listing_id                                             0.029352
# price                                                 -0.059969
# host_is_superhost                                      0.008479
# accommodates                                          -0.078361
# bathrooms                                             -0.018782
# bedrooms                                              -0.047254
# beds                                                  -0.047804
# minimum_nights                                        -0.033568
# maximum_nights                                        -0.021254
# number_of_reviews                                     -0.023071
# review_scores_rating                                   0.030919
# instant_bookable                                       0.053868
# reviews_per_month                                     -0.009851
# cancellation_policy_moderate                          -0.010279
# cancellation_policy_strict_14_with_grace_period        0.024088
# bed_type_Couch                                        -0.011923
# bed_type_Futon                                         1.000000
# bed_type_Pull-out Sofa                                -0.027557
# bed_type_Real Bed                                     -0.530955
# room_type_Private room                                 0.099531
# room_type_Shared room                                 -0.015070
#
#                                                  bed_type_Pull-out Sofa  \
# listing_id                                                     0.016262
# price                                                         -0.091895
# host_is_superhost                                              0.012380
# accommodates                                                  -0.098329
# bathrooms                                                     -0.047397
# bedrooms                                                      -0.060277
# beds                                                          -0.088247
# minimum_nights                                                -0.025687
# maximum_nights                                                -0.012163
# number_of_reviews                                             -0.005994
# review_scores_rating                                          -0.004456
# instant_bookable                                               0.052870
# reviews_per_month                                              0.012672
# cancellation_policy_moderate                                   0.039307
# cancellation_policy_strict_14_with_grace_period               -0.037360
# bed_type_Couch                                                -0.016789
# bed_type_Futon                                                -0.027557
# bed_type_Pull-out Sofa                                         1.000000
# bed_type_Real Bed                                             -0.747680
# room_type_Private room                                         0.131419
# room_type_Shared room                                         -0.024560
#
#                                                  bed_type_Real Bed  \
# listing_id                                               -0.040292
# price                                                     0.097855
# host_is_superhost                                        -0.016140
# accommodates                                              0.132100
# bathrooms                                                 0.063859
# bedrooms                                                  0.089079
# beds                                                      0.106590
# minimum_nights                                            0.048585
# maximum_nights                                            0.024182
# number_of_reviews                                         0.013197
# review_scores_rating                                     -0.001463
# instant_bookable                                         -0.059368
# reviews_per_month                                        -0.008825
# cancellation_policy_moderate                             -0.024659
# cancellation_policy_strict_14_with_grace_period           0.019404
# bed_type_Couch                                           -0.323491
# bed_type_Futon                                           -0.530955
# bed_type_Pull-out Sofa                                   -0.747680
# bed_type_Real Bed                                         1.000000
# room_type_Private room                                   -0.174763
# room_type_Shared room                                     0.004647
#
#                                                  room_type_Private room  \
# listing_id                                                     0.097214
# price                                                         -0.359554
# host_is_superhost                                             -0.069841
# accommodates                                                  -0.388546
# bathrooms                                                     -0.021248
# bedrooms                                                      -0.211334
# beds                                                          -0.302090
# minimum_nights                                                -0.189646
# maximum_nights                                                -0.046396
# number_of_reviews                                             -0.014000
# review_scores_rating                                           0.080324
# instant_bookable                                               0.126266
# reviews_per_month                                              0.030980
# cancellation_policy_moderate                                   0.087462
# cancellation_policy_strict_14_with_grace_period               -0.191364
# bed_type_Couch                                                 0.035806
# bed_type_Futon                                                 0.099531
# bed_type_Pull-out Sofa                                         0.131419
# bed_type_Real Bed                                             -0.174763
# room_type_Private room                                         1.000000
# room_type_Shared room                                         -0.098897
#
#                                                  room_type_Shared room
# listing_id                                                    0.035981
# price                                                        -0.087744
# host_is_superhost                                             0.042907
# accommodates                                                  0.150963
# bathrooms                                                    -0.163130
# bedrooms                                                     -0.042116
# beds                                                          0.229646
# minimum_nights                                               -0.038177
# maximum_nights                                               -0.025114
# number_of_reviews                                             0.000062
# review_scores_rating                                         -0.098383
# instant_bookable                                              0.037043
# reviews_per_month                                             0.014344
# cancellation_policy_moderate                                  0.028034
# cancellation_policy_strict_14_with_grace_period              -0.008871
# bed_type_Couch                                                0.067640
# bed_type_Futon                                               -0.015070
# bed_type_Pull-out Sofa                                       -0.024560
# bed_type_Real Bed                                             0.004647
# room_type_Private room                                       -0.098897
# room_type_Shared room                                         1.000000
#
# [21 rows x 21 columns]

# %%
plt.figure(figsize=(20, 20))
ax = sns.heatmap(large_df.corr(),
            vmin=-1,
            vmax=1,
            cmap=sns.diverging_palette(220,10,n=51)
           )

# %%
#  Just to visualize prices
ax = large_df.loc[:, 'price'].plot(figsize=(20,8))

# %%
ax = large_df.loc[:, 'host_is_superhost'].hist(figsize=(20,8))

# %%
ax = large_df.loc[:, 'accommodates'].hist(figsize=(20,8))

# %%
ax = large_df.loc[:, 'bathrooms'].hist(figsize=(20,8))

# %%
ax = large_df.loc[:, 'bedrooms'].hist(figsize=(20,8))

# %%
ax = large_df.loc[:, 'beds'].hist(figsize=(20,8))

# %%
#  Clearly the singular datapont over at ~900 is messing with the data. I'll clear that up later
ax = large_df.loc[:, 'minimum_nights'].hist(figsize=(20,8), bins=20)

# %%
#  Clearly the singular datapont over at ~900 is messing with the data. I'll clear that up later
ax = large_df.loc[:, 'maximum_nights'].hist(figsize=(20,8), bins=20)

# %%
ax = large_df.loc[:, 'number_of_reviews'].hist(figsize=(20,8), bins=20)

# %%
ax = large_df.loc[:, 'review_scores_rating'].hist(figsize=(20,8), bins=20)

# %%
ax = large_df.loc[:, 'instant_bookable'].hist(figsize=(20,8), bins=2)

# %%
ax = large_df.loc[:, 'reviews_per_month'].hist(figsize=(20,8), bins=20)

# %%
ax = large_df.loc[:, 'cancellation_policy_moderate'].hist(figsize=(20,8), bins=2)

# %%
ax = large_df.loc[:, 'cancellation_policy_strict_14_with_grace_period'].hist(figsize=(20,8), bins=2)

# %%
ax = large_df.loc[:, 'bed_type_Couch'].hist(figsize=(20,8), bins=2)

# %%
ax = large_df.loc[:, 'bed_type_Futon'].hist(figsize=(20,8), bins=2)

# %%
ax = large_df.loc[:, 'bed_type_Pull-out Sofa'].hist(figsize=(20,8), bins=2)

# %%
ax = large_df.loc[:, 'bed_type_Real Bed'].hist(figsize=(20,8), bins=2)

# %%
ax = large_df.loc[:, 'room_type_Private room'].hist(figsize=(20,8), bins=2)

# %%
ax = large_df.loc[:, 'room_type_Shared room'].hist(figsize=(20,8), bins=2)

# %% [markdown]
# Some of the major shortcomings of the datasets as I see it include:
# - There is no variable similar to 'is_holiday.' Day of the week, weekend vs. not, month, etc had no relationship to price, but I imagine prices rae higher around certain holidays (e.g., Christmas, New Years, others). I can hardcode these, and I might, but it would be nice if I didn't have to.
# - There is no variable for the age or gender of either the renter or rentee. I would be curious to see if those interactions had any impact, but short of some NLP work on the names, there's little I can do on gender and nothing on age.
# - I wish more of the info were more standardized. For instance, the amenities feature is just a list of things the apartment has (e.g., wifi, laundry, kitchen) but it is entered by the property owner and is in no way standardized, and so it is effectively unusable as a feature, even though it would be quite handy probably.
# - There is no way of knowing when a listing was available but not rented, as far as I can tell, which throws off the idea of free market supply and demand auto-regulating, as I can't know when something is priced too high.
#
# I don't think these shortcomings really necessitate any assumptions on my part, but they definitely limit the work I can do and conclusions I can draw. I guess I just have to assume that things like WiFi, laundry, w/e is not an important feature (though I don't believe that to be true).

# %% [markdown]
# Things I intend to improve:
# - I intend to work in the neighborhoods csv, since there are only like ~12 or so neighborhoods in the set I could include it as a categorical variable attempting to account for area of town.
# - I probably want to include holidays, both domestic and international, as I think it probably has an impact.
# - Certain data points, while likely valid, are just such outliers (whether in terms of price or other features) that I think they aren't that representative and would like to exclude them most likely.
# - Fine tuning the tradeoff between model bias and variance. The variance is already quite low (the R^2 of the test set is within .0001 of the training set), so I can definitely afford to increase complexity a bit.
# - I have been treating this as a non-time-series dataset, but I'm curious what it would look like if I applied time-series techniques.

# %% [markdown]
# I have chosen RMSE and R^2 as my evaluation metrics. I prefer RMSE to MSE simply because it's more intuitive and of a scale we are more used to, and I prefer RMSE in this case to MAE because being really wrong once does matter to the stated goals of this model (namely, provide a useful estimate for the optimum price point). R^2 is also just a useful all-around metric and is one people are relatively used to seeing in the wild
